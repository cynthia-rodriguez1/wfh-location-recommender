# %% [markdown]
# ## Modeling
#
# For background on this project, please see the [README](../README.md).
#
# **Notebooks**
# - [Data Acquisition & Cleaning](./01_data_acq_clean.ipynb)
# - [Exploratory Data Analysis](./02_eda.ipynb)
# - Modeling (this notebook)
# - [Results and Recommendations](./04_results.ipynb)
#
# **In this notebook, you'll find:**
# - Classification models using content-based filtering
# - Brief analyses for each model

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

from scipy import sparse, spatial
import sys
from sklearn.metrics.pairwise import pairwise_distances, cosine_similarity, cosine_distances

from numpy import dot
from numpy.linalg import norm

# %% [markdown]
# ---
# #### **Importing All-Feature Dataframe**
#
# This is the aggregated dataframe of all of our datasets.

# %%
model_df = pd.read_csv('../datasets/cleaned_data/all_features.csv')

model_df.head()
# Out:
#        place state       price  auto_accss_idx  pct_no_vehicle  \
# 0  Asheville    NC  225.830385        0.580614        0.053756
# 1     Austin    TX  436.273137        0.718323        0.059187
# 2     Boston    MA  272.879054        0.759096        0.301252
# 3  Cambridge    MA  246.035242        0.563985        0.102769
# 4    Chicago    IL  245.904608        0.636256        0.169022
#
#    pct_one_or_more_vehicles  transit_accss_idx  walkability_idx  \
# 0                  0.946244           0.149850         9.382035
# 1                  0.940813           0.286952        11.516379
# 2                  0.698748           0.409262        14.936791
# 3                  0.897231           0.160956        12.458517
# 4                  0.830978           0.310866        13.635529
#
#    cost_of_living  grocery_cost_idx  ...  nov_avg_rain  dec_avg_rain  \
# 0           105.7             103.1  ...          3.11          3.69
# 1           129.4              96.7  ...          2.52          2.42
# 2           153.4             111.4  ...          4.04          4.01
# 3           173.7             115.5  ...          4.00          3.85
# 4           107.4              97.2  ...          2.44          2.04
#
#    winter_avg_temp  spring_avg_temp  summer_avg_temp  autumn_avg_temp  \
# 0        40.166667        53.333333        70.200000        55.333333
# 1        53.400000        67.433333        82.333333        70.366667
# 2        33.100000        49.700000        72.233333        56.000000
# 3        31.100000        49.166667        71.633333        54.533333
# 4        28.133333        50.833333        73.933333        55.766667
#
#    winter_avg_rain  spring_avg_rain  summer_avg_rain  autumn_avg_rain
# 0         3.710000         4.160000         4.713333         3.423333
# 1         2.243333         3.256667         2.386667         3.026667
# 2         3.810000         3.790000         3.463333         3.703333
# 3         3.570000         3.706667         3.523333         3.676667
# 4         1.760000         3.223333         3.643333         2.853333
#
# [5 rows x 52 columns]

# %%
model_df.columns
# Out:
# Index(['place', 'state', 'price', 'auto_accss_idx', 'pct_no_vehicle',
#        'pct_one_or_more_vehicles', 'transit_accss_idx', 'walkability_idx',
#        'cost_of_living', 'grocery_cost_idx', 'transportation_cost_idx',
#        'miscellaneous_cost_idx', 'population', 'median_age',
#        'summer_comfort_index', 'winter_comfort_index',
#        'perc_growth_since_2020', 'political_left_lean', 'political_right_lean',
#        'chain_ratio', 'jan_avg_temp', 'feb_avg_temp', 'march_avg_temp',
#        'april_avg_temp', 'may_avg_temp', 'june_avg_temp', 'july_avg_temp',
#        'aug_avg_temp', 'sept_avg_temp', 'oct_avg_temp', 'nov_avg_temp',
#        'dec_avg_temp', 'jan_avg_rain', 'feb_avg_rain', 'mar_avg_rain',
#        'apr_avg_rain', 'may_avg_rain', 'jun_avg_rain', 'jul_avg_rain',
#        'aug_avg_rain', 'sep_avg_rain', 'oct_avg_rain', 'nov_avg_rain',
#        'dec_avg_rain', 'winter_avg_temp', 'spring_avg_temp', 'summer_avg_temp',
#        'autumn_avg_temp', 'winter_avg_rain', 'spring_avg_rain',
#        'summer_avg_rain', 'autumn_avg_rain'],
#       dtype='object')

# %%
model_df['miscellaneous_cost_idx'].mean()
# Out:
# 129.34484848484846

# %%
model_df[['place', 'winter_avg_temp', 'spring_avg_temp', 'summer_avg_temp', 'autumn_avg_temp']]
# Out:
#               place  winter_avg_temp  spring_avg_temp  summer_avg_temp  \
# 0         Asheville        40.166667        53.333333        70.200000
# 1            Austin        53.400000        67.433333        82.333333
# 2            Boston        33.100000        49.700000        72.233333
# 3         Cambridge        31.100000        49.166667        71.633333
# 4           Chicago        28.133333        50.833333        73.933333
# 5          Columbus        32.866667        52.800000        74.100000
# 6            Dallas        49.566667        64.800000        82.666667
# 7            Denver        33.166667        47.200000        73.466667
# 8   Fort Lauderdale        70.300000        75.933333        82.533333
# 9        Fort Worth        49.166667        64.100000        82.133333
# 10           Hawaii        71.653333        73.183333        76.863333
# 11      Jersey City        36.933333        53.500000        76.166667
# 12            Kauai        78.333333        79.333333        84.000000
# 13        Las Vegas        47.033333        63.333333        87.200000
# 14      Los Angeles        51.100000        59.433333        76.866667
# 15             Maui        73.500000        75.833333        80.166667
# 16        Nashville        42.933333        59.033333        77.966667
# 17      New Orleans        57.200000        69.133333        82.333333
# 18    New York City        37.260000        53.300000        75.953333
# 19           Newark        35.300000        52.633333        75.133333
# 20             Oahu        73.500000        76.166667        81.000000
# 21          Oakland        49.400000        57.266667        70.900000
# 22         Portland        39.666667        49.783333        67.166667
# 23     Rhode Island        34.046667        49.053333        71.680000
# 24            Salem        38.300000        48.166667        66.566667
# 25        San Diego        52.900000        59.633333        76.833333
# 26    San Francisco        51.333333        55.166667        62.200000
# 27        San Mateo        50.566667        54.300000        63.566667
# 28      Santa Clara        48.433333        55.766667        70.866667
# 29       Santa Cruz        50.500000        54.700000        65.866667
# 30          Seattle        35.533333        46.033333        63.033333
# 31      Twin Cities        17.985714        47.714286        73.219048
# 32    Washington DC        39.166667        56.300000        77.333333
#
#     autumn_avg_temp
# 0         55.333333
# 1         70.366667
# 2         56.000000
# 3         54.533333
# 4         55.766667
# 5         56.733333
# 6         68.900000
# 7         55.600000
# 8         77.633333
# 9         68.533333
# 10        76.416667
# 11        59.466667
# 12        83.000000
# 13        67.333333
# 14        65.633333
# 15        79.000000
# 16        60.533333
# 17        70.700000
# 18        59.853333
# 19        57.966667
# 20        79.666667
# 21        62.300000
# 22        52.833333
# 23        56.360000
# 24        51.700000
# 25        66.866667
# 26        60.000000
# 27        60.333333
# 28        62.166667
# 29        61.433333
# 30        48.833333
# 31        51.257143
# 32        60.066667

# %%
model_df['place'] = model_df[['place', 'state']].apply(lambda x: ', '.join(x), axis=1)
model_df.drop(columns='state', inplace=True)
model_df.head()
# model_df = model_df[['']]
# Out:
#            place       price  auto_accss_idx  pct_no_vehicle  \
# 0  Asheville, NC  225.830385        0.580614        0.053756
# 1     Austin, TX  436.273137        0.718323        0.059187
# 2     Boston, MA  272.879054        0.759096        0.301252
# 3  Cambridge, MA  246.035242        0.563985        0.102769
# 4    Chicago, IL  245.904608        0.636256        0.169022
#
#    pct_one_or_more_vehicles  transit_accss_idx  walkability_idx  \
# 0                  0.946244           0.149850         9.382035
# 1                  0.940813           0.286952        11.516379
# 2                  0.698748           0.409262        14.936791
# 3                  0.897231           0.160956        12.458517
# 4                  0.830978           0.310866        13.635529
#
#    cost_of_living  grocery_cost_idx  transportation_cost_idx  ...  \
# 0           105.7             103.1                     82.8  ...
# 1           129.4              96.7                    109.9  ...
# 2           153.4             111.4                    131.8  ...
# 3           173.7             115.5                     95.7  ...
# 4           107.4              97.2                    138.5  ...
#
#    nov_avg_rain  dec_avg_rain  winter_avg_temp  spring_avg_temp  \
# 0          3.11          3.69        40.166667        53.333333
# 1          2.52          2.42        53.400000        67.433333
# 2          4.04          4.01        33.100000        49.700000
# 3          4.00          3.85        31.100000        49.166667
# 4          2.44          2.04        28.133333        50.833333
#
#    summer_avg_temp  autumn_avg_temp  winter_avg_rain  spring_avg_rain  \
# 0        70.200000        55.333333         3.710000         4.160000
# 1        82.333333        70.366667         2.243333         3.256667
# 2        72.233333        56.000000         3.810000         3.790000
# 3        71.633333        54.533333         3.570000         3.706667
# 4        73.933333        55.766667         1.760000         3.223333
#
#    summer_avg_rain  autumn_avg_rain
# 0         4.713333         3.423333
# 1         2.386667         3.026667
# 2         3.463333         3.703333
# 3         3.523333         3.676667
# 4         3.643333         2.853333
#
# [5 rows x 51 columns]

# %%
trial_model_df = model_df[['place', 'winter_avg_temp', 'summer_avg_temp', 'chain_ratio', 'walkability_idx', 'political_left_lean', 'political_right_lean', 'miscellaneous_cost_idx', 'price']]

# %%
trial_model_df.head()
# Out:
#            place  winter_avg_temp  summer_avg_temp  walkability_idx  \
# 0  Asheville, NC        40.166667        70.200000         9.382035
# 1     Austin, TX        53.400000        82.333333        11.516379
# 2     Boston, MA        33.100000        72.233333        14.936791
# 3  Cambridge, MA        31.100000        71.633333        12.458517
# 4    Chicago, IL        28.133333        73.933333        13.635529
#
#    chain_ratio  political_left_lean  political_right_lean  \
# 0       0.3516                0.597                 0.386
# 1       0.3814                0.714                 0.264
# 2       0.2796                0.806                 0.175
# 3       0.3277                0.715                 0.263
# 4       0.3717                0.742                 0.240
#
#    miscellaneous_cost_idx       price
# 0                   111.2  225.830385
# 1                   105.9  436.273137
# 2                   157.9  272.879054
# 3                   176.7  246.035242
# 4                   139.8  245.904608

# %%
# Converting price column to monthly cost with Airbnb's estimated 30+day-stay discount
trial_model_df['avg_monthly_price'] = (trial_model_df['price'] * 30) - ((trial_model_df['price'] * 30) * 0.25)
trial_model_df.drop(columns=['price'], inplace=True)
trial_model_df.head()
# Out:
# /var/folders/td/_057xlcn5px5szx_85_2v2dc0000gn/T/ipykernel_1621/397421596.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trial_model_df['avg_monthly_price'] = (trial_model_df['price'] * 30) - ((trial_model_df['price'] * 30) * 0.25)
# /var/folders/td/_057xlcn5px5szx_85_2v2dc0000gn/T/ipykernel_1621/397421596.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trial_model_df.drop(columns=['price'], inplace=True)
#            place  winter_avg_temp  summer_avg_temp  walkability_idx  \
# 0  Asheville, NC        40.166667        70.200000         9.382035
# 1     Austin, TX        53.400000        82.333333        11.516379
# 2     Boston, MA        33.100000        72.233333        14.936791
# 3  Cambridge, MA        31.100000        71.633333        12.458517
# 4    Chicago, IL        28.133333        73.933333        13.635529
#
#    chain_ratio  political_left_lean  political_right_lean  \
# 0       0.3516                0.597                 0.386
# 1       0.3814                0.714                 0.264
# 2       0.2796                0.806                 0.175
# 3       0.3277                0.715                 0.263
# 4       0.3717                0.742                 0.240
#
#    miscellaneous_cost_idx  avg_monthly_price
# 0                   111.2        5081.183654
# 1                   105.9        9816.145585
# 2                   157.9        6139.778716
# 3                   176.7        5535.792952
# 4                   139.8        5532.853672

# %%
trial_model_df
# Out:
#                   place  winter_avg_temp  summer_avg_temp  walkability_idx  \
# 0         Asheville, NC        40.166667        70.200000         9.382035
# 1            Austin, TX        53.400000        82.333333        11.516379
# 2            Boston, MA        33.100000        72.233333        14.936791
# 3         Cambridge, MA        31.100000        71.633333        12.458517
# 4           Chicago, IL        28.133333        73.933333        13.635529
# 5          Columbus, OH        32.866667        74.100000        11.556746
# 6            Dallas, TX        49.566667        82.666667        11.899341
# 7            Denver, CO        33.166667        73.466667        14.462231
# 8   Fort Lauderdale, FL        70.300000        82.533333        12.445745
# 9        Fort Worth, TX        49.166667        82.133333         9.585953
# 10           Hawaii, HI        71.653333        76.863333         4.986450
# 11      Jersey City, NJ        36.933333        76.166667        14.382772
# 12            Kauai, HI        78.333333        84.000000         6.059524
# 13        Las Vegas, NV        47.033333        87.200000        11.957625
# 14      Los Angeles, CA        51.100000        76.866667        13.572348
# 15             Maui, HI        73.500000        80.166667         6.703883
# 16        Nashville, TN        42.933333        77.966667        10.727273
# 17      New Orleans, LA        57.200000        82.333333        13.797787
# 18    New York City, NY        37.260000        75.953333        13.491196
# 19           Newark, NJ        35.300000        75.133333        13.334575
# 20             Oahu, HI        73.500000        81.000000        11.998872
# 21          Oakland, CA        49.400000        70.900000        14.138809
# 22         Portland, OR        39.666667        67.166667        14.395631
# 23     Rhode Island, RI        34.046667        71.680000        12.587935
# 24            Salem, OR        38.300000        66.566667        11.864583
# 25        San Diego, CA        52.900000        76.833333        12.186630
# 26    San Francisco, CA        51.333333        62.200000        15.957258
# 27        San Mateo, CA        50.566667        63.566667        10.069474
# 28      Santa Clara, CA        48.433333        70.866667        13.554884
# 29       Santa Cruz, CA        50.500000        65.866667        11.977041
# 30          Seattle, WA        35.533333        63.033333        12.875176
# 31      Twin Cities, MN        17.985714        73.219048        11.519265
# 32    Washington DC, DC        39.166667        77.333333        14.471481
#
#     chain_ratio  political_left_lean  political_right_lean  \
# 0        0.3516               0.5970                0.3860
# 1        0.3814               0.7140                0.2640
# 2        0.2796               0.8060                0.1750
# 3        0.3277               0.7150                0.2630
# 4        0.3717               0.7420                0.2400
# 5        0.5012               0.6470                0.3340
# 6        0.4783               0.6490                0.3330
# 7        0.3274               0.7960                0.1820
# 8        0.3837               0.6450                0.3470
# 9        0.5595               0.4930                0.4910
# 10       0.1536               0.6690                0.3060
# 11       0.2848               0.7240                0.2620
# 12       0.1136               0.6340                0.3460
# 13       0.4390               0.5370                0.4430
# 14       0.3708               0.7100                0.2690
# 15       0.1745               0.6660                0.3110
# 16       0.4119               0.6450                0.3240
# 17       0.2144               0.8310                0.1500
# 18       0.2385               0.7210                0.2680
# 19       0.2986               0.7710                0.2180
# 20       0.2745               0.6250                0.3570
# 21       0.3128               0.7980                0.1760
# 22       0.2949               0.7920                0.1790
# 23       0.3076               0.5986                0.3806
# 24       0.3920               0.4890                0.4770
# 25       0.3636               0.6020                0.3750
# 26       0.1687               0.8530                0.1270
# 27       0.3135               0.7790                0.2020
# 28       0.3904               0.7260                0.2520
# 29       0.2999               0.7840                0.1850
# 30       0.3041               0.7500                0.2220
# 31       0.4743               0.7100                0.2665
# 32       0.2882               0.9210                0.0540
#
#     miscellaneous_cost_idx  avg_monthly_price
# 0                   111.20        5081.183654
# 1                   105.90        9816.145585
# 2                   157.90        6139.778716
# 3                   176.70        5535.792952
# 4                   139.80        5532.853672
# 5                   107.50        3835.510118
# 6                   107.80        5658.053279
# 7                   152.20        4313.462492
# 8                   107.60        5663.896761
# 9                   109.20        4079.534543
# 10                  103.00        8001.008898
# 11                  112.90        7618.616379
# 12                   92.90       10624.326246
# 13                  109.70        6133.315182
# 14                  133.20        7949.752689
# 15                   95.30       14795.287657
# 16                   99.90        6680.137795
# 17                   97.70        4606.418306
# 18                  137.90        5547.651086
# 19                  109.90        4728.013926
# 20                  124.00        7105.221072
# 21                  158.50        4255.004470
# 22                  140.10        3437.974960
# 23                  121.18        8775.806865
# 24                  103.60        3764.578652
# 25                  152.90        8439.955478
# 26                  162.60        6337.010744
# 27                  161.20        6917.916918
# 28                  158.40        5461.467443
# 29                  155.60        8101.685328
# 30                  150.70        4502.591812
# 31                  143.40        6895.659449
# 32                  168.00        4445.793998

# %%
walk_mean = trial_model_df['walkability_idx'].mean()
walk_std = trial_model_df['walkability_idx'].std()

# %%
walk_input_options = ['Not important at all', 'Not very important', 'Neutral', 'A little important', 'Very important']

# %%
walk_input_index = [walk_mean - (2*walk_std), walk_mean - (1*walk_std), walk_mean, walk_mean + (1*walk_std), walk_mean + (2*walk_std)]

# %%
walk_input_index
# Out:
# [7.077144672571502,
#  9.576295608226786,
#  12.07544654388207,
#  14.574597479537353,
#  17.073748415192636]

# %%
walkability_mapper = dict(zip(walk_input_options, walk_input_index))
walkability_mapper
# Out:
# {'Not important at all': 7.077144672571502,
#  'Not very important': 9.576295608226786,
#  'Neutral': 12.07544654388207,
#  'A little important': 14.574597479537353,
#  'Very important': 17.073748415192636}

# %%
trial_model_df.describe()
# Out:
#        winter_avg_temp  summer_avg_temp  walkability_idx  chain_ratio  \
# count        33.000000        33.000000        33.000000    33.000000
# mean         46.471082        74.791385        12.075447     0.328676
# std          14.479006         6.471081         2.499151     0.100857
# min          17.985714        62.200000         4.986450     0.113600
# 25%          35.533333        70.900000        11.519265     0.284800
# 50%          47.033333        75.133333        12.445745     0.313500
# 75%          51.333333        80.166667        13.635529     0.383700
# max          78.333333        87.200000        15.957258     0.559500
#
#        political_left_lean  political_right_lean  miscellaneous_cost_idx  \
# count            33.000000             33.000000               33.000000
# mean              0.701200              0.277730              129.344848
# std               0.100124              0.100504               25.397655
# min               0.489000              0.054000               92.900000
# 25%               0.645000              0.202000              107.600000
# 50%               0.714000              0.266500              124.000000
# 75%               0.779000              0.346000              152.900000
# max               0.921000              0.491000              176.700000
#
#        avg_monthly_price
# count          33.000000
# mean         6387.315367
# std          2347.730358
# min          3437.974960
# 25%          4606.418306
# 50%          5663.896761
# 75%          7618.616379
# max         14795.287657

# %%
trial_model_df[['place', 'miscellaneous_cost_idx']].sort_values(by='miscellaneous_cost_idx', ascending=False)
# Out:
#                   place  miscellaneous_cost_idx
# 3         Cambridge, MA                  176.70
# 32    Washington DC, DC                  168.00
# 26    San Francisco, CA                  162.60
# 27        San Mateo, CA                  161.20
# 21          Oakland, CA                  158.50
# 28      Santa Clara, CA                  158.40
# 2            Boston, MA                  157.90
# 29       Santa Cruz, CA                  155.60
# 25        San Diego, CA                  152.90
# 7            Denver, CO                  152.20
# 30          Seattle, WA                  150.70
# 31      Twin Cities, MN                  143.40
# 22         Portland, OR                  140.10
# 4           Chicago, IL                  139.80
# 18    New York City, NY                  137.90
# 33         User Input_3                  135.00
# 14      Los Angeles, CA                  133.20
# 20             Oahu, HI                  124.00
# 23     Rhode Island, RI                  121.18
# 11      Jersey City, NJ                  112.90
# 0         Asheville, NC                  111.20
# 19           Newark, NJ                  109.90
# 13        Las Vegas, NV                  109.70
# 9        Fort Worth, TX                  109.20
# 6            Dallas, TX                  107.80
# 8   Fort Lauderdale, FL                  107.60
# 5          Columbus, OH                  107.50
# 1            Austin, TX                  105.90
# 24            Salem, OR                  103.60
# 10           Hawaii, HI                  103.00
# 16        Nashville, TN                   99.90
# 17      New Orleans, LA                   97.70
# 15             Maui, HI                   95.30
# 12            Kauai, HI                   92.90

# %%
user_input = ['User Input', 65, 75, 'I like to try new restaurants', 'Neutral', 'Moderate left lean preferred', 5, 6000]

# can we turn this into a dictionary?

# %%
user_input[5]
# Out:
# 'Moderate left lean preferred'

# %%
for i in walkability_mapper:
    print(i[0])
# Out:
# Not important at all
# Not very important
# Neutral
# A little important
# Very important

# %%
pol_pref_options = ['Strong left lean preferred', 'Moderate left lean preferred', 'Moderate right lean preferred', 'Strong right lean preferred']
pol_pref_nums = [.9, .8, .6, .5]

pol_dem_mapper = list(zip(pol_pref_options, pol_pref_nums))
pol_dem_mapper
# Out:
# [('Strong left lean preferred', 0.9),
#  ('Moderate left lean preferred', 0.8),
#  ('Moderate right lean preferred', 0.6),
#  ('Strong right lean preferred', 0.5)]

# %%
trial_model_df['chain_ratio'].std()
# Out:
# 0.10085718873208491

# %%
[i[1] for i in pol_dem_mapper if user_input[5] == i[0]]
# Out:
# [0.8]

# %%
for i in walkability_mapper:
    if user_input[4] == i[0]:
        print(i[1])
        user_walk_index = i[1]
# Out:
# 12.07544654388207

# %%
walkability_mapper
# Out:
# {'Not important at all': 7.077144672571502,
#  'Not very important': 9.576295608226786,
#  'Neutral': 12.07544654388207,
#  'A little important': 14.574597479537353,
#  'Very important': 17.073748415192636}

# %%
for k, v in walkability_mapper.items():
    print(k)
    print(v)
# Out:
# Not important at all
# 7.077144672571502
# Not very important
# 9.576295608226786
# Neutral
# 12.07544654388207
# A little important
# 14.574597479537353
# Very important
# 17.073748415192636

# %%
if user_input[5] == 'No':
    user_pol_dem = .7
else:
    user_pol_dem = [i[1] for i in pol_dem_mapper if user_input[5] == i[0]]   

print(user_pol_dem[0])
# Out:
# 0.8

# %%
user_input = ['User Input', 65, 75, 12.07544654388207, 0.25, 0.8, 0.2, 155, 6000]

# %%
len(user_input)
# Out:
# 9

# %%
user_input_2 = ['User Input_2', 70, 80, 12.07544654388207, 0.30, 0.7, 0.3, 140, 6000]

# %%
user_input_3 = ['User Input_3', 65, 75, 14.574597479537353, 0.2, 0.85, 0.15, 135, 5500]

# %%
trial_model_df.loc[len(trial_model_df)] = user_input_3
# Out:
# /var/folders/td/_057xlcn5px5szx_85_2v2dc0000gn/T/ipykernel_1621/1424498399.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trial_model_df.loc[len(trial_model_df)] = user_input_3

# %%
trial_model_df.describe()
# Out:
#        winter_avg_temp  summer_avg_temp  walkability_idx  chain_ratio  \
# count        34.000000        34.000000        34.000000    34.000000
# mean         47.016050        74.797521        12.148951     0.324891
# std          14.607755         6.372381         2.498037     0.101739
# min          17.985714        62.200000         4.986450     0.113600
# 25%          35.883333        71.083333        11.528635     0.280900
# 50%          47.733333        75.066667        12.452131     0.313150
# 75%          52.508333        79.616667        13.757222     0.383125
# max          78.333333        87.200000        15.957258     0.559500
#
#        political_left_lean  political_right_lean  miscellaneous_cost_idx  \
# count            34.000000             34.000000               34.000000
# mean              0.705576              0.273974              129.511176
# std               0.101844              0.101364               25.028679
# min               0.489000              0.054000               92.900000
# 25%               0.645000              0.189250              107.650000
# 50%               0.714500              0.265250              128.600000
# 75%               0.782750              0.343000              152.725000
# max               0.921000              0.491000              176.700000
#
#        avg_monthly_price
# count          34.000000
# mean         6361.217857
# std          2316.887820
# min          3437.974960
# 25%          4636.817211
# 50%          5660.975020
# 75%          7490.267552
# max         14795.287657

# %%
trial_model_df
# Out:
#                   place  winter_avg_temp  summer_avg_temp  walkability_idx  \
# 0         Asheville, NC        40.166667        70.200000         9.382035
# 1            Austin, TX        53.400000        82.333333        11.516379
# 2            Boston, MA        33.100000        72.233333        14.936791
# 3         Cambridge, MA        31.100000        71.633333        12.458517
# 4           Chicago, IL        28.133333        73.933333        13.635529
# 5          Columbus, OH        32.866667        74.100000        11.556746
# 6            Dallas, TX        49.566667        82.666667        11.899341
# 7            Denver, CO        33.166667        73.466667        14.462231
# 8   Fort Lauderdale, FL        70.300000        82.533333        12.445745
# 9        Fort Worth, TX        49.166667        82.133333         9.585953
# 10           Hawaii, HI        71.653333        76.863333         4.986450
# 11      Jersey City, NJ        36.933333        76.166667        14.382772
# 12            Kauai, HI        78.333333        84.000000         6.059524
# 13        Las Vegas, NV        47.033333        87.200000        11.957625
# 14      Los Angeles, CA        51.100000        76.866667        13.572348
# 15             Maui, HI        73.500000        80.166667         6.703883
# 16        Nashville, TN        42.933333        77.966667        10.727273
# 17      New Orleans, LA        57.200000        82.333333        13.797787
# 18    New York City, NY        37.260000        75.953333        13.491196
# 19           Newark, NJ        35.300000        75.133333        13.334575
# 20             Oahu, HI        73.500000        81.000000        11.998872
# 21          Oakland, CA        49.400000        70.900000        14.138809
# 22         Portland, OR        39.666667        67.166667        14.395631
# 23     Rhode Island, RI        34.046667        71.680000        12.587935
# 24            Salem, OR        38.300000        66.566667        11.864583
# 25        San Diego, CA        52.900000        76.833333        12.186630
# 26    San Francisco, CA        51.333333        62.200000        15.957258
# 27        San Mateo, CA        50.566667        63.566667        10.069474
# 28      Santa Clara, CA        48.433333        70.866667        13.554884
# 29       Santa Cruz, CA        50.500000        65.866667        11.977041
# 30          Seattle, WA        35.533333        63.033333        12.875176
# 31      Twin Cities, MN        17.985714        73.219048        11.519265
# 32    Washington DC, DC        39.166667        77.333333        14.471481
# 33         User Input_3        65.000000        75.000000        14.574597
#
#     chain_ratio  political_left_lean  political_right_lean  \
# 0        0.3516               0.5970                0.3860
# 1        0.3814               0.7140                0.2640
# 2        0.2796               0.8060                0.1750
# 3        0.3277               0.7150                0.2630
# 4        0.3717               0.7420                0.2400
# 5        0.5012               0.6470                0.3340
# 6        0.4783               0.6490                0.3330
# 7        0.3274               0.7960                0.1820
# 8        0.3837               0.6450                0.3470
# 9        0.5595               0.4930                0.4910
# 10       0.1536               0.6690                0.3060
# 11       0.2848               0.7240                0.2620
# 12       0.1136               0.6340                0.3460
# 13       0.4390               0.5370                0.4430
# 14       0.3708               0.7100                0.2690
# 15       0.1745               0.6660                0.3110
# 16       0.4119               0.6450                0.3240
# 17       0.2144               0.8310                0.1500
# 18       0.2385               0.7210                0.2680
# 19       0.2986               0.7710                0.2180
# 20       0.2745               0.6250                0.3570
# 21       0.3128               0.7980                0.1760
# 22       0.2949               0.7920                0.1790
# 23       0.3076               0.5986                0.3806
# 24       0.3920               0.4890                0.4770
# 25       0.3636               0.6020                0.3750
# 26       0.1687               0.8530                0.1270
# 27       0.3135               0.7790                0.2020
# 28       0.3904               0.7260                0.2520
# 29       0.2999               0.7840                0.1850
# 30       0.3041               0.7500                0.2220
# 31       0.4743               0.7100                0.2665
# 32       0.2882               0.9210                0.0540
# 33       0.2000               0.8500                0.1500
#
#     miscellaneous_cost_idx  avg_monthly_price
# 0                   111.20        5081.183654
# 1                   105.90        9816.145585
# 2                   157.90        6139.778716
# 3                   176.70        5535.792952
# 4                   139.80        5532.853672
# 5                   107.50        3835.510118
# 6                   107.80        5658.053279
# 7                   152.20        4313.462492
# 8                   107.60        5663.896761
# 9                   109.20        4079.534543
# 10                  103.00        8001.008898
# 11                  112.90        7618.616379
# 12                   92.90       10624.326246
# 13                  109.70        6133.315182
# 14                  133.20        7949.752689
# 15                   95.30       14795.287657
# 16                   99.90        6680.137795
# 17                   97.70        4606.418306
# 18                  137.90        5547.651086
# 19                  109.90        4728.013926
# 20                  124.00        7105.221072
# 21                  158.50        4255.004470
# 22                  140.10        3437.974960
# 23                  121.18        8775.806865
# 24                  103.60        3764.578652
# 25                  152.90        8439.955478
# 26                  162.60        6337.010744
# 27                  161.20        6917.916918
# 28                  158.40        5461.467443
# 29                  155.60        8101.685328
# 30                  150.70        4502.591812
# 31                  143.40        6895.659449
# 32                  168.00        4445.793998
# 33                  135.00        5500.000000

# %%
test = model_df[['place', 'price', 'pct_no_vehicle', 'cost_of_living', 'walkability_idx', 'chain_ratio']]

# %%
trial_model_df.columns
# Out:
# Index(['place', 'winter_avg_temp', 'summer_avg_temp', 'walkability_idx',
#        'chain_ratio', 'political_left_lean', 'political_right_lean',
#        'miscellaneous_cost_idx', 'avg_monthly_price'],
#       dtype='object')

# %%
feature_cols = ['winter_avg_temp', 'summer_avg_temp', 'walkability_idx',
       'chain_ratio', 'political_left_lean', 'political_right_lean',
       'miscellaneous_cost_idx', 'avg_monthly_price']

sc = MinMaxScaler()
scaled_trial = sc.fit_transform(trial_model_df[feature_cols])

print(scaled_trial[:2])
# Out:
# [[0.36755307 0.32       0.40066191 0.53375196 0.25       0.7597254
#   0.21837709 0.14468288]
#  [0.58683816 0.80533333 0.59520954 0.60058309 0.52083333 0.4805492
#   0.15513126 0.56159153]]

# %%
indices = pd.Series(trial_model_df.index, index=trial_model_df['place'])

cosine = cosine_similarity(scaled_trial)

def place_recommender(place_name, model=cosine):
    index = indices[place_name]

    scores = list(enumerate(model[index]))

    sim_scores = sorted(scores, key= lambda x:x[1], reverse=True)
    sim_scores = sim_scores[1:11]

    top_recs_index = [i[0] for i in sim_scores]

    top_places = trial_model_df['place'].iloc[top_recs_index]

    return top_places

# %%
indices
# Out:
# place
# Asheville, NC           0
# Austin, TX              1
# Boston, MA              2
# Cambridge, MA           3
# Chicago, IL             4
# Columbus, OH            5
# Dallas, TX              6
# Denver, CO              7
# Fort Lauderdale, FL     8
# Fort Worth, TX          9
# Hawaii, HI             10
# Jersey City, NJ        11
# Kauai, HI              12
# Las Vegas, NV          13
# Los Angeles, CA        14
# Maui, HI               15
# Nashville, TN          16
# New Orleans, LA        17
# New York City, NY      18
# Newark, NJ             19
# Oahu, HI               20
# Oakland, CA            21
# Portland, OR           22
# Rhode Island, RI       23
# Salem, OR              24
# San Diego, CA          25
# San Francisco, CA      26
# San Mateo, CA          27
# Santa Clara, CA        28
# Santa Cruz, CA         29
# Seattle, WA            30
# Twin Cities, MN        31
# Washington DC, DC      32
# User Input_3           33
# dtype: int64

# %%
print('Recommended Places:')
print(place_recommender('User Input_3', cosine).values)
# Out:
# Recommended Places:
# ['Oakland, CA' 'New Orleans, LA' 'Portland, OR' 'New York City, NY'
#  'Washington DC, DC' 'Boston, MA' 'Newark, NJ' 'San Francisco, CA'
#  'Los Angeles, CA' 'Denver, CO']

# %%
similarity_scores = sorted(list(enumerate(cosine[indices['San Francisco, CA']])), key= lambda x:x[1], reverse=True)

# %%
[i[0] for i in similarity_scores]
# Out:
# [26,
#  29,
#  22,
#  21,
#  30,
#  2,
#  33,
#  27,
#  32,
#  7,
#  28,
#  3,
#  18,
#  4,
#  14,
#  19,
#  11,
#  25,
#  17,
#  31,
#  23,
#  20,
#  1,
#  8,
#  0,
#  6,
#  16,
#  5,
#  10,
#  24,
#  13,
#  15,
#  12,
#  9]

# %%
trial_model_df['place'].iloc[[i[0] for i in similarity_scores]]
# Out:
# 26      San Francisco, CA
# 29         Santa Cruz, CA
# 22           Portland, OR
# 21            Oakland, CA
# 30            Seattle, WA
# 2              Boston, MA
# 33           User Input_3
# 27          San Mateo, CA
# 32      Washington DC, DC
# 7              Denver, CO
# 28        Santa Clara, CA
# 3           Cambridge, MA
# 18      New York City, NY
# 4             Chicago, IL
# 14        Los Angeles, CA
# 19             Newark, NJ
# 11        Jersey City, NJ
# 25          San Diego, CA
# 17        New Orleans, LA
# 31        Twin Cities, MN
# 23       Rhode Island, RI
# 20               Oahu, HI
# 1              Austin, TX
# 8     Fort Lauderdale, FL
# 0           Asheville, NC
# 6              Dallas, TX
# 16          Nashville, TN
# 5            Columbus, OH
# 10             Hawaii, HI
# 24              Salem, OR
# 13          Las Vegas, NV
# 15               Maui, HI
# 12              Kauai, HI
# 9          Fort Worth, TX
# Name: place, dtype: object

# %%
list(enumerate(cosine[indices['San Francisco, CA']]))
# Out:
# [(0, 0.6193912742600769),
#  (1, 0.6663204108168225),
#  (2, 0.9357412021223088),
#  (3, 0.8657516959803817),
#  (4, 0.8395501792898792),
#  (5, 0.5982463256055518),
#  (6, 0.6021465000932469),
#  (7, 0.9031081772719182),
#  (8, 0.6470090012206144),
#  (9, 0.39795593080947744),
#  (10, 0.508528500018575),
#  (11, 0.8026399584354277),
#  (12, 0.4351730226961039),
#  (13, 0.4970843593989582),
#  (14, 0.8213301133178844),
#  (15, 0.48973877309779135),
#  (16, 0.5999687496506284),
#  (17, 0.7483638945425544),
#  (18, 0.8631268510337504),
#  (19, 0.8089178836193812),
#  (20, 0.7030865468392643),
#  (21, 0.9416791504997746),
#  (22, 0.9422408807616666),
#  (23, 0.7171311974160652),
#  (24, 0.5064231347577338),
#  (25, 0.755175841221089),
#  (26, 1.0000000000000002),
#  (27, 0.9174870444316416),
#  (28, 0.8899594919509353),
#  (29, 0.9448331426029035),
#  (30, 0.938926867318185),
#  (31, 0.7249665443563678),
#  (32, 0.905169599864383),
#  (33, 0.9184636375596953)]

# %%
indices
# Out:
# place
# Asheville, NC           0
# Austin, TX              1
# Boston, MA              2
# Cambridge, MA           3
# Chicago, IL             4
# Columbus, OH            5
# Dallas, TX              6
# Denver, CO              7
# Fort Lauderdale, FL     8
# Fort Worth, TX          9
# Hawaii, HI             10
# Jersey City, NJ        11
# Kauai, HI              12
# Las Vegas, NV          13
# Los Angeles, CA        14
# Maui, HI               15
# Nashville, TN          16
# New Orleans, LA        17
# New York City, NY      18
# Newark, NJ             19
# Oahu, HI               20
# Oakland, CA            21
# Portland, OR           22
# Rhode Island, RI       23
# Salem, OR              24
# San Diego, CA          25
# San Francisco, CA      26
# San Mateo, CA          27
# Santa Clara, CA        28
# Santa Cruz, CA         29
# Seattle, WA            30
# Twin Cities, MN        31
# Washington DC, DC      32
# User Input_3           33
# dtype: int64

# %%
cosine_distances(model_df.iloc[:, 2:])
# Out:
# array([[0.00000000e+00, 4.29554703e-06, 3.87045136e-06, ...,
#         4.06008214e-06, 4.11825903e-06, 3.83185116e-06],
#        [4.29554703e-06, 0.00000000e+00, 1.85363105e-08, ...,
#         1.21248582e-08, 8.32707103e-09, 1.91021039e-08],
#        [3.87045136e-06, 1.85363105e-08, 0.00000000e+00, ...,
#         3.12543202e-09, 6.59206745e-09, 3.81653376e-10],
#        ...,
#        [4.06008214e-06, 1.21248582e-08, 3.12543202e-09, ...,
#         0.00000000e+00, 5.97219252e-09, 4.69485928e-09],
#        [4.11825903e-06, 8.32707103e-09, 6.59206745e-09, ...,
#         5.97219252e-09, 0.00000000e+00, 7.30497374e-09],
#        [3.83185116e-06, 1.91021039e-08, 3.81653376e-10, ...,
#         4.69485928e-09, 7.30497374e-09, 0.00000000e+00]])

# %%
pairwise_distances(model_df.iloc[:, 2:], metric='cosine')
# Out:
# array([[4.44089210e-16, 4.29554703e-06, 3.87045136e-06, ...,
#         4.06008214e-06, 4.11825903e-06, 3.83185116e-06],
#        [4.29554703e-06, 4.44089210e-16, 1.85363105e-08, ...,
#         1.21248582e-08, 8.32707103e-09, 1.91021039e-08],
#        [3.87045136e-06, 1.85363105e-08, 0.00000000e+00, ...,
#         3.12543202e-09, 6.59206745e-09, 3.81653376e-10],
#        ...,
#        [4.06008214e-06, 1.21248582e-08, 3.12543202e-09, ...,
#         5.55111512e-16, 5.97219252e-09, 4.69485928e-09],
#        [4.11825903e-06, 8.32707103e-09, 6.59206745e-09, ...,
#         5.97219252e-09, 0.00000000e+00, 7.30497374e-09],
#        [3.83185116e-06, 1.91021038e-08, 3.81653376e-10, ...,
#         4.69485939e-09, 7.30497351e-09, 0.00000000e+00]])

# %%
similarity_matrix= cosine_similarity(model_df.iloc[:, 2:])

sys.getsizeof(similarity_matrix)
# Out:
# 8840

# %%
similarity_matrix
# Out:
# array([[1.        , 0.9999957 , 0.99999613, ..., 0.99999594, 0.99999588,
#         0.99999617],
#        [0.9999957 , 1.        , 0.99999998, ..., 0.99999999, 0.99999999,
#         0.99999998],
#        [0.99999613, 0.99999998, 1.        , ..., 1.        , 0.99999999,
#         1.        ],
#        ...,
#        [0.99999594, 0.99999999, 1.        , ..., 1.        , 0.99999999,
#         1.        ],
#        [0.99999588, 0.99999999, 0.99999999, ..., 0.99999999, 1.        ,
#         0.99999999],
#        [0.99999617, 0.99999998, 1.        , ..., 1.        , 0.99999999,
#         1.        ]])

# %%
pd.DataFrame(cosine_similarity(model_df.iloc[:, 2:]), index = model_df['place'], columns=model_df['place'])
# Out:
# place                Asheville, NC  Austin, TX  Boston, MA  Cambridge, MA  \
# place
# Asheville, NC             1.000000    0.999996    0.999996       1.000000
# Austin, TX                0.999996    1.000000    1.000000       0.999996
# Boston, MA                0.999996    1.000000    1.000000       0.999997
# Cambridge, MA             1.000000    0.999996    0.999997       1.000000
# Chicago, IL               0.999995    1.000000    1.000000       0.999996
# Columbus, OH              0.999996    1.000000    1.000000       0.999996
# Dallas, TX                0.999995    1.000000    1.000000       0.999996
# Denver, CO                0.999996    1.000000    1.000000       0.999997
# Fort Lauderdale, FL       0.999999    0.999998    0.999999       0.999999
# Fort Worth, TX            0.999996    1.000000    1.000000       0.999996
# Hawaii, HI                0.999999    0.999999    0.999999       0.999999
# Jersey City, NJ           0.999998    1.000000    1.000000       0.999998
# Kauai, HI                 0.999996    0.999985    0.999986       0.999995
# Las Vegas, NV             0.999996    1.000000    1.000000       0.999997
# Los Angeles, CA           0.999995    1.000000    1.000000       0.999995
# Maui, HI                  0.999999    0.999998    0.999998       0.999999
# Nashville, TN             0.999996    1.000000    1.000000       0.999997
# New Orleans, LA           0.999997    1.000000    1.000000       0.999998
# New York City, NY         0.999995    1.000000    1.000000       0.999995
# Newark, NJ                0.999998    1.000000    1.000000       0.999998
# Oahu, HI                  0.999996    1.000000    1.000000       0.999997
# Oakland, CA               0.999997    1.000000    1.000000       0.999998
# Portland, OR              0.999996    1.000000    1.000000       0.999997
# Rhode Island, RI          0.999996    1.000000    1.000000       0.999996
# Salem, OR                 0.999999    0.999999    0.999999       0.999999
# San Diego, CA             0.999995    1.000000    1.000000       0.999996
# San Francisco, CA         0.999996    1.000000    1.000000       0.999997
# San Mateo, CA             0.999996    1.000000    1.000000       0.999997
# Santa Clara, CA           0.999995    1.000000    1.000000       0.999996
# Santa Cruz, CA            0.999998    0.999999    1.000000       0.999999
# Seattle, WA               0.999996    1.000000    1.000000       0.999997
# Twin Cities, MN           0.999996    1.000000    1.000000       0.999997
# Washington DC, DC         0.999996    1.000000    1.000000       0.999997
#
# place                Chicago, IL  Columbus, OH  Dallas, TX  Denver, CO  \
# place
# Asheville, NC           0.999995      0.999996    0.999995    0.999996
# Austin, TX              1.000000      1.000000    1.000000    1.000000
# Boston, MA              1.000000      1.000000    1.000000    1.000000
# Cambridge, MA           0.999996      0.999996    0.999996    0.999997
# Chicago, IL             1.000000      1.000000    1.000000    1.000000
# Columbus, OH            1.000000      1.000000    1.000000    1.000000
# Dallas, TX              1.000000      1.000000    1.000000    1.000000
# Denver, CO              1.000000      1.000000    1.000000    1.000000
# Fort Lauderdale, FL     0.999998      0.999998    0.999998    0.999999
# Fort Worth, TX          1.000000      1.000000    1.000000    1.000000
# Hawaii, HI              0.999998      0.999999    0.999999    0.999999
# Jersey City, NJ         0.999999      0.999999    0.999999    1.000000
# Kauai, HI               0.999984      0.999985    0.999984    0.999985
# Las Vegas, NV           1.000000      1.000000    1.000000    1.000000
# Los Angeles, CA         1.000000      1.000000    1.000000    1.000000
# Maui, HI                0.999997      0.999998    0.999998    0.999998
# Nashville, TN           1.000000      1.000000    1.000000    1.000000
# New Orleans, LA         1.000000      1.000000    1.000000    1.000000
# New York City, NY       1.000000      1.000000    1.000000    1.000000
# Newark, NJ              0.999999      1.000000    1.000000    1.000000
# Oahu, HI                1.000000      1.000000    1.000000    1.000000
# Oakland, CA             1.000000      1.000000    1.000000    1.000000
# Portland, OR            1.000000      1.000000    1.000000    1.000000
# Rhode Island, RI        1.000000      1.000000    1.000000    1.000000
# Salem, OR               0.999999      0.999999    0.999999    0.999999
# San Diego, CA           1.000000      1.000000    1.000000    1.000000
# San Francisco, CA       1.000000      1.000000    1.000000    1.000000
# San Mateo, CA           1.000000      1.000000    1.000000    1.000000
# Santa Clara, CA         1.000000      1.000000    1.000000    1.000000
# Santa Cruz, CA          0.999999      0.999999    0.999999    1.000000
# Seattle, WA             1.000000      1.000000    1.000000    1.000000
# Twin Cities, MN         1.000000      1.000000    1.000000    1.000000
# Washington DC, DC       1.000000      1.000000    1.000000    1.000000
#
# place                Fort Lauderdale, FL  Fort Worth, TX  ...  \
# place                                                     ...
# Asheville, NC                   0.999999        0.999996  ...
# Austin, TX                      0.999998        1.000000  ...
# Boston, MA                      0.999999        1.000000  ...
# Cambridge, MA                   0.999999        0.999996  ...
# Chicago, IL                     0.999998        1.000000  ...
# Columbus, OH                    0.999998        1.000000  ...
# Dallas, TX                      0.999998        1.000000  ...
# Denver, CO                      0.999999        1.000000  ...
# Fort Lauderdale, FL             1.000000        0.999998  ...
# Fort Worth, TX                  0.999998        1.000000  ...
# Hawaii, HI                      1.000000        0.999999  ...
# Jersey City, NJ                 1.000000        1.000000  ...
# Kauai, HI                       0.999993        0.999985  ...
# Las Vegas, NV                   0.999999        1.000000  ...
# Los Angeles, CA                 0.999998        1.000000  ...
# Maui, HI                        1.000000        0.999998  ...
# Nashville, TN                   0.999999        1.000000  ...
# New Orleans, LA                 0.999999        1.000000  ...
# New York City, NY               0.999998        1.000000  ...
# Newark, NJ                      1.000000        1.000000  ...
# Oahu, HI                        0.999999        1.000000  ...
# Oakland, CA                     0.999999        1.000000  ...
# Portland, OR                    0.999999        1.000000  ...
# Rhode Island, RI                0.999998        1.000000  ...
# Salem, OR                       1.000000        0.999999  ...
# San Diego, CA                   0.999998        1.000000  ...
# San Francisco, CA               0.999999        1.000000  ...
# San Mateo, CA                   0.999999        1.000000  ...
# Santa Clara, CA                 0.999998        1.000000  ...
# Santa Cruz, CA                  1.000000        0.999999  ...
# Seattle, WA                     0.999999        1.000000  ...
# Twin Cities, MN                 0.999999        1.000000  ...
# Washington DC, DC               0.999999        1.000000  ...
#
# place                Rhode Island, RI  Salem, OR  San Diego, CA  \
# place
# Asheville, NC                0.999996   0.999999       0.999995
# Austin, TX                   1.000000   0.999999       1.000000
# Boston, MA                   1.000000   0.999999       1.000000
# Cambridge, MA                0.999996   0.999999       0.999996
# Chicago, IL                  1.000000   0.999999       1.000000
# Columbus, OH                 1.000000   0.999999       1.000000
# Dallas, TX                   1.000000   0.999999       1.000000
# Denver, CO                   1.000000   0.999999       1.000000
# Fort Lauderdale, FL          0.999998   1.000000       0.999998
# Fort Worth, TX               1.000000   0.999999       1.000000
# Hawaii, HI                   0.999999   1.000000       0.999998
# Jersey City, NJ              0.999999   1.000000       0.999999
# Kauai, HI                    0.999985   0.999991       0.999984
# Las Vegas, NV                1.000000   0.999999       1.000000
# Los Angeles, CA              1.000000   0.999999       1.000000
# Maui, HI                     0.999998   1.000000       0.999997
# Nashville, TN                1.000000   0.999999       1.000000
# New Orleans, LA              1.000000   1.000000       1.000000
# New York City, NY            1.000000   0.999999       1.000000
# Newark, NJ                   1.000000   1.000000       0.999999
# Oahu, HI                     1.000000   0.999999       1.000000
# Oakland, CA                  1.000000   1.000000       1.000000
# Portland, OR                 1.000000   0.999999       1.000000
# Rhode Island, RI             1.000000   0.999999       1.000000
# Salem, OR                    0.999999   1.000000       0.999999
# San Diego, CA                1.000000   0.999999       1.000000
# San Francisco, CA            1.000000   0.999999       1.000000
# San Mateo, CA                1.000000   0.999999       1.000000
# Santa Clara, CA              1.000000   0.999999       1.000000
# Santa Cruz, CA               0.999999   1.000000       0.999999
# Seattle, WA                  1.000000   0.999999       1.000000
# Twin Cities, MN              1.000000   0.999999       1.000000
# Washington DC, DC            1.000000   0.999999       1.000000
#
# place                San Francisco, CA  San Mateo, CA  Santa Clara, CA  \
# place
# Asheville, NC                 0.999996       0.999996         0.999995
# Austin, TX                    1.000000       1.000000         1.000000
# Boston, MA                    1.000000       1.000000         1.000000
# Cambridge, MA                 0.999997       0.999997         0.999996
# Chicago, IL                   1.000000       1.000000         1.000000
# Columbus, OH                  1.000000       1.000000         1.000000
# Dallas, TX                    1.000000       1.000000         1.000000
# Denver, CO                    1.000000       1.000000         1.000000
# Fort Lauderdale, FL           0.999999       0.999999         0.999998
# Fort Worth, TX                1.000000       1.000000         1.000000
# Hawaii, HI                    0.999999       0.999999         0.999999
# Jersey City, NJ               1.000000       1.000000         0.999999
# Kauai, HI                     0.999985       0.999986         0.999984
# Las Vegas, NV                 1.000000       1.000000         1.000000
# Los Angeles, CA               1.000000       1.000000         1.000000
# Maui, HI                      0.999998       0.999998         0.999998
# Nashville, TN                 1.000000       1.000000         1.000000
# New Orleans, LA               1.000000       1.000000         1.000000
# New York City, NY             1.000000       1.000000         1.000000
# Newark, NJ                    1.000000       1.000000         1.000000
# Oahu, HI                      1.000000       1.000000         1.000000
# Oakland, CA                   1.000000       1.000000         1.000000
# Portland, OR                  1.000000       1.000000         1.000000
# Rhode Island, RI              1.000000       1.000000         1.000000
# Salem, OR                     0.999999       0.999999         0.999999
# San Diego, CA                 1.000000       1.000000         1.000000
# San Francisco, CA             1.000000       1.000000         1.000000
# San Mateo, CA                 1.000000       1.000000         1.000000
# Santa Clara, CA               1.000000       1.000000         1.000000
# Santa Cruz, CA                1.000000       1.000000         0.999999
# Seattle, WA                   1.000000       1.000000         1.000000
# Twin Cities, MN               1.000000       1.000000         1.000000
# Washington DC, DC             1.000000       1.000000         1.000000
#
# place                Santa Cruz, CA  Seattle, WA  Twin Cities, MN  \
# place
# Asheville, NC              0.999998     0.999996         0.999996
# Austin, TX                 0.999999     1.000000         1.000000
# Boston, MA                 1.000000     1.000000         1.000000
# Cambridge, MA              0.999999     0.999997         0.999997
# Chicago, IL                0.999999     1.000000         1.000000
# Columbus, OH               0.999999     1.000000         1.000000
# Dallas, TX                 0.999999     1.000000         1.000000
# Denver, CO                 1.000000     1.000000         1.000000
# Fort Lauderdale, FL        1.000000     0.999999         0.999999
# Fort Worth, TX             0.999999     1.000000         1.000000
# Hawaii, HI                 1.000000     0.999999         0.999999
# Jersey City, NJ            1.000000     1.000000         1.000000
# Kauai, HI                  0.999990     0.999985         0.999985
# Las Vegas, NV              1.000000     1.000000         1.000000
# Los Angeles, CA            0.999999     1.000000         1.000000
# Maui, HI                   0.999999     0.999998         0.999998
# Nashville, TN              1.000000     1.000000         1.000000
# New Orleans, LA            1.000000     1.000000         1.000000
# New York City, NY          0.999999     1.000000         1.000000
# Newark, NJ                 1.000000     1.000000         1.000000
# Oahu, HI                   1.000000     1.000000         1.000000
# Oakland, CA                1.000000     1.000000         1.000000
# Portland, OR               1.000000     1.000000         1.000000
# Rhode Island, RI           0.999999     1.000000         1.000000
# Salem, OR                  1.000000     0.999999         0.999999
# San Diego, CA              0.999999     1.000000         1.000000
# San Francisco, CA          1.000000     1.000000         1.000000
# San Mateo, CA              1.000000     1.000000         1.000000
# Santa Clara, CA            0.999999     1.000000         1.000000
# Santa Cruz, CA             1.000000     1.000000         1.000000
# Seattle, WA                1.000000     1.000000         1.000000
# Twin Cities, MN            1.000000     1.000000         1.000000
# Washington DC, DC          1.000000     1.000000         1.000000
#
# place                Washington DC, DC
# place
# Asheville, NC                 0.999996
# Austin, TX                    1.000000
# Boston, MA                    1.000000
# Cambridge, MA                 0.999997
# Chicago, IL                   1.000000
# Columbus, OH                  1.000000
# Dallas, TX                    1.000000
# Denver, CO                    1.000000
# Fort Lauderdale, FL           0.999999
# Fort Worth, TX                1.000000
# Hawaii, HI                    0.999999
# Jersey City, NJ               1.000000
# Kauai, HI                     0.999986
# Las Vegas, NV                 1.000000
# Los Angeles, CA               1.000000
# Maui, HI                      0.999998
# Nashville, TN                 1.000000
# New Orleans, LA               1.000000
# New York City, NY             1.000000
# Newark, NJ                    1.000000
# Oahu, HI                      1.000000
# Oakland, CA                   1.000000
# Portland, OR                  1.000000
# Rhode Island, RI              1.000000
# Salem, OR                     0.999999
# San Diego, CA                 1.000000
# San Francisco, CA             1.000000
# San Mateo, CA                 1.000000
# Santa Clara, CA               1.000000
# Santa Cruz, CA                1.000000
# Seattle, WA                   1.000000
# Twin Cities, MN               1.000000
# Washington DC, DC             1.000000
#
# [33 rows x 33 columns]

# %%
model_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   place                     33 non-null     object
#  1   price                     33 non-null     float64
#  2   auto_accss_idx            33 non-null     float64
#  3   pct_no_vehicle            33 non-null     float64
#  4   pct_one_or_more_vehicles  33 non-null     float64
#  5   transit_accss_idx         33 non-null     float64
#  6   walkability_idx           33 non-null     float64
#  7   cost_of_living            33 non-null     float64
#  8   grocery_cost_idx          33 non-null     float64
#  9   transportation_cost_idx   33 non-null     float64
#  10  miscellaneous_cost_idx    33 non-null     float64
#  11  population                33 non-null     int64
#  12  median_age                33 non-null     float64
#  13  summer_comfort_index      33 non-null     float64
#  14  winter_comfort_index      33 non-null     float64
#  15  perc_growth_since_2020    33 non-null     float64
#  16  political_left_lean       33 non-null     float64
#  17  political_right_lean      33 non-null     float64
#  18  chain_ratio               33 non-null     float64
#  19  jan_avg_temp              33 non-null     float64
#  20  feb_avg_temp              33 non-null     float64
#  21  march_avg_temp            33 non-null     float64
#  22  april_avg_temp            33 non-null     float64
#  23  may_avg_temp              33 non-null     float64
#  24  june_avg_temp             33 non-null     float64
#  25  july_avg_temp             33 non-null     float64
#  26  aug_avg_temp              33 non-null     float64
#  27  sept_avg_temp             33 non-null     float64
#  28  oct_avg_temp              33 non-null     float64
#  29  nov_avg_temp              33 non-null     float64
#  30  dec_avg_temp              33 non-null     float64
#  31  jan_avg_rain              33 non-null     float64
#  32  feb_avg_rain              33 non-null     float64
#  33  mar_avg_rain              33 non-null     float64
#  34  apr_avg_rain              33 non-null     float64
#  35  may_avg_rain              33 non-null     float64
#  36  jun_avg_rain              33 non-null     float64
#  37  jul_avg_rain              33 non-null     float64
#  38  aug_avg_rain              33 non-null     float64
#  39  sep_avg_rain              33 non-null     float64
#  40  oct_avg_rain              33 non-null     float64
#  41  nov_avg_rain              33 non-null     float64
#  42  dec_avg_rain              33 non-null     float64
#  43  winter_avg_temp           33 non-null     float64
#  44  spring_avg_temp           33 non-null     float64
#  45  summer_avg_temp           33 non-null     float64
#  46  autumn_avg_temp           33 non-null     float64
#  47  winter_avg_rain           33 non-null     float64
#  48  spring_avg_rain           33 non-null     float64
#  49  summer_avg_rain           33 non-null     float64
#  50  autumn_avg_rain           33 non-null     float64
# dtypes: float64(49), int64(1), object(1)
# memory usage: 13.3+ KB

# %%
# We're seeing the most nulls in the neighborhood group column

model_df.isnull().sum().sum()
# Out:
# 0

# %%
# Fortunately, we don't have much use for the columns that have null values, so we'll be dropping these and a few others
# Neighborhood group included here because we'll only need the neighborhood column for our analysis

airbnb.drop(columns=['name', 'host_id', 'host_name', 'neighbourhood_group', 'minimum_nights'], inplace=True) 
old_shape = airbnb.shape
old_shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/cynthiarodriguez/Desktop/DSI-822/Projects/wfh-location-recommender/notebooks/03_modeling.ipynb Cell 60 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/cynthiarodriguez/Desktop/DSI-822/Projects/wfh-location-recommender/notebooks/03_modeling.ipynb#Y113sZmlsZQ%3D%3D?line=0'>1</a> # Fortunately, we don't have much use for the columns that have null values, so we'll be dropping these and a few others
#       <a href='vscode-notebook-cell:/Users/cynthiarodriguez/Desktop/DSI-822/Projects/wfh-location-recommender/notebooks/03_modeling.ipynb#Y113sZmlsZQ%3D%3D?line=1'>2</a> # Neighborhood group included here because we'll only need the neighborhood column for our analysis
# ----> <a href='vscode-notebook-cell:/Users/cynthiarodriguez/Desktop/DSI-822/Projects/wfh-location-recommender/notebooks/03_modeling.ipynb#Y113sZmlsZQ%3D%3D?line=3'>4</a> airbnb.drop(columns=['name', 'host_id', 'host_name', 'neighbourhood_group', 'minimum_nights'], inplace=True)
#       <a href='vscode-notebook-cell:/Users/cynthiarodriguez/Desktop/DSI-822/Projects/wfh-location-recommender/notebooks/03_modeling.ipynb#Y113sZmlsZQ%3D%3D?line=4'>5</a> old_shape = airbnb.shape
#       <a href='vscode-notebook-cell:/Users/cynthiarodriguez/Desktop/DSI-822/Projects/wfh-location-recommender/notebooks/03_modeling.ipynb#Y113sZmlsZQ%3D%3D?line=5'>6</a> old_shape
#
# NameError: name 'airbnb' is not defined

# %%
# Checking for and removing any duplicate listings in the data
# Keeping none as I don't feel that we could accurately/fairly determine which city to leave the listing in for

airbnb.drop_duplicates(subset=['id'], keep=False, inplace=True)
print(f'Total listings dropped: {old_shape[0] - airbnb.shape[0]}')
# Out:
# Total listings dropped: 10151

# %%
airbnb['room_type'].value_counts()
# Out:
# Entire home/apt    202199
# Private room        62695
# Shared room          2765
# Hotel room           1184
# Name: room_type, dtype: int64
